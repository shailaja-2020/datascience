# %% [markdown]
# ## Assignment- Airlines data
# Perform clustering (hierarchical,K means clustering and DBSCAN) for the airlines data to obtain optimum number of clusters.
# Draw the inferences from the clusters obtained.

# %%
# import hierarchical clustering libraries
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
air=pd.read_csv("c:/users/mahesh/datasetcsv/airlines.csv")

# %%
air.shape
# Out:
# (3999, 12)

# %% [markdown]
# # Data preprocessing

# %%
air=air.iloc[:,1:]

# %%
air.dtypes
# Out:
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# Award                int64
# dtype: object

# %%
air=air.drop(columns='Qual_miles')

# %%
air.head()
# Out:
#    Balance  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0    28143          1          1          1          174            1
# 1    19244          1          1          1          215            2
# 2    41354          1          1          1         4123            4
# 3    14776          1          1          1          500            1
# 4    97752          4          1          1        43300           26
#
#    Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0                  0                0               7000      0
# 1                  0                0               6968      0
# 2                  0                0               7034      0
# 3                  0                0               6952      0
# 4               2077                4               6935      1

# %%
air.isnull().sum()
# Out:
# Balance              0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award                0
# dtype: int64

# %%
air.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3994    False
# 3995    False
# 3996    False
# 3997    False
# 3998    False
# Length: 3999, dtype: bool

# %%
air.shape
# Out:
# (3999, 10)

# %%
# data normalisation

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
df_norm = norm_func(air.iloc[:,:])

# %%
df_norm.head(5)
# Out:
#     Balance  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0  0.016508       0.00        0.0        0.0     0.000660     0.011628
# 1  0.011288       0.00        0.0        0.0     0.000815     0.023256
# 2  0.024257       0.00        0.0        0.0     0.015636     0.046512
# 3  0.008667       0.00        0.0        0.0     0.001896     0.011628
# 4  0.057338       0.75        0.0        0.0     0.164211     0.302326
#
#    Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0           0.000000         0.000000           0.843742    0.0
# 1           0.000000         0.000000           0.839884    0.0
# 2           0.000000         0.000000           0.847842    0.0
# 3           0.000000         0.000000           0.837955    0.0
# 4           0.067398         0.075472           0.835905    1.0

# %%
airdend=df_norm.drop(columns='Days_since_enroll')

# %%
airdend.head(5)
# Out:
#     Balance  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0  0.016508       0.00        0.0        0.0     0.000660     0.011628
# 1  0.011288       0.00        0.0        0.0     0.000815     0.023256
# 2  0.024257       0.00        0.0        0.0     0.015636     0.046512
# 3  0.008667       0.00        0.0        0.0     0.001896     0.011628
# 4  0.057338       0.75        0.0        0.0     0.164211     0.302326
#
#    Flight_miles_12mo  Flight_trans_12  Award
# 0           0.000000         0.000000    0.0
# 1           0.000000         0.000000    0.0
# 2           0.000000         0.000000    0.0
# 3           0.000000         0.000000    0.0
# 4           0.067398         0.075472    1.0

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
df_norm1 = norm_func(airdend.iloc[:,:])

# %%
df_norm1.shape
# Out:
# (3999, 9)

# %%
# create dendrogram
plt.figure(figsize=(15,15))
dendrogram = sch.dendrogram(sch.linkage(df_norm1,method='single'))

# %%
# create clusters
hc = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'single')

# %%
# save clusters for chart
y_hc = hc.fit_predict(air)
Clusters=pd.DataFrame(y_hc,columns=['Clusters'])

# %%
df_norm1['Cluster']=Clusters

# %%
df_norm1
# Out:
#        Balance  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0     0.016508       0.00        0.0        0.0     0.000660     0.011628
# 1     0.011288       0.00        0.0        0.0     0.000815     0.023256
# 2     0.024257       0.00        0.0        0.0     0.015636     0.046512
# 3     0.008667       0.00        0.0        0.0     0.001896     0.011628
# 4     0.057338       0.75        0.0        0.0     0.164211     0.302326
# ...        ...        ...        ...        ...          ...          ...
# 3994  0.010837       0.00        0.0        0.0     0.032330     0.046512
# 3995  0.037766       0.00        0.0        0.0     0.003720     0.058140
# 3996  0.043169       0.50        0.0        0.0     0.096505     0.093023
# 3997  0.032202       0.00        0.0        0.0     0.001896     0.011628
# 3998  0.001769       0.00        0.0        0.0     0.000000     0.000000
#
#       Flight_miles_12mo  Flight_trans_12  Award  Cluster
# 0              0.000000         0.000000    0.0        0
# 1              0.000000         0.000000    0.0        0
# 2              0.000000         0.000000    0.0        0
# 3              0.000000         0.000000    0.0        0
# 4              0.067398         0.075472    1.0        0
# ...                 ...              ...    ...      ...
# 3994           0.006490         0.018868    1.0        0
# 3995           0.000000         0.000000    1.0        0
# 3996           0.000000         0.000000    1.0        0
# 3997           0.016225         0.018868    0.0        0
# 3998           0.000000         0.000000    0.0        0
#
# [3999 rows x 10 columns]

# %% [markdown]
# # Clustering using K means

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans

# %%
km=df_norm.iloc[:,0:]

# %%
km.head(5)
# Out:
#     Balance  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0  0.016508       0.00        0.0        0.0     0.000660     0.011628
# 1  0.011288       0.00        0.0        0.0     0.000815     0.023256
# 2  0.024257       0.00        0.0        0.0     0.015636     0.046512
# 3  0.008667       0.00        0.0        0.0     0.001896     0.011628
# 4  0.057338       0.75        0.0        0.0     0.164211     0.302326
#
#    Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0           0.000000         0.000000           0.843742    0.0
# 1           0.000000         0.000000           0.839884    0.0
# 2           0.000000         0.000000           0.847842    0.0
# 3           0.000000         0.000000           0.837955    0.0
# 4           0.067398         0.075472           0.835905    1.0

# %% [markdown]
# # How to find optimum number of  cluster
# #The K-means algorithm aims to choose centroids that minimise the inertia, or within-cluster sum-of-squares criterion:

# %%
wcss = []
for i in range(1, 6):
    kmeans = KMeans(n_clusters=i,random_state=0)
    kmeans.fit(km)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 6), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#Build Cluster algorithm
from sklearn.cluster import KMeans
clusters_new = KMeans(4, random_state=42)
clusters_new.fit(km)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
clusters_new.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
#Assign clusters to the data set
km['clusterid_new'] = clusters_new.labels_
# Out:
# <ipython-input-31-833e89a4b17f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   km['clusterid_new'] = clusters_new.labels_

# %%
km
# Out:
#        Balance  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0     0.016508       0.00        0.0        0.0     0.000660     0.011628
# 1     0.011288       0.00        0.0        0.0     0.000815     0.023256
# 2     0.024257       0.00        0.0        0.0     0.015636     0.046512
# 3     0.008667       0.00        0.0        0.0     0.001896     0.011628
# 4     0.057338       0.75        0.0        0.0     0.164211     0.302326
# ...        ...        ...        ...        ...          ...          ...
# 3994  0.010837       0.00        0.0        0.0     0.032330     0.046512
# 3995  0.037766       0.00        0.0        0.0     0.003720     0.058140
# 3996  0.043169       0.50        0.0        0.0     0.096505     0.093023
# 3997  0.032202       0.00        0.0        0.0     0.001896     0.011628
# 3998  0.001769       0.00        0.0        0.0     0.000000     0.000000
#
#       Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# 0              0.000000         0.000000           0.843742    0.0
# 1              0.000000         0.000000           0.839884    0.0
# 2              0.000000         0.000000           0.847842    0.0
# 3              0.000000         0.000000           0.837955    0.0
# 4              0.067398         0.075472           0.835905    1.0
# ...                 ...              ...                ...    ...
# 3994           0.006490         0.018868           0.168917    1.0
# 3995           0.000000         0.000000           0.167953    1.0
# 3996           0.000000         0.000000           0.168797    1.0
# 3997           0.016225         0.018868           0.168676    0.0
# 3998           0.000000         0.000000           0.168314    0.0
#
#       clusterid_new
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 1
# ...             ...
# 3994              2
# 3995              2
# 3996              1
# 3997              0
# 3998              0
#
# [3999 rows x 11 columns]

# %%
km.sort_values(by=["clusterid_new"])
# Out:
#        Balance  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0     0.016508       0.00        0.0        0.0     0.000660     0.011628
# 2421  0.024086       0.00        0.5        0.0     0.031382     0.127907
# 2424  0.008409       0.00        0.0        0.0     0.000000     0.000000
# 2426  0.071203       0.00        0.0        0.0     0.032235     0.046512
# 2429  0.039894       0.00        0.0        0.0     0.000937     0.034884
# ...        ...        ...        ...        ...          ...          ...
# 2307  0.102851       0.75        0.0        0.0     0.152273     0.220930
# 3397  0.056151       1.00        0.0        0.0     0.212796     0.162791
# 2305  0.115070       0.75        0.0        0.0     0.128509     0.151163
# 452   0.106926       0.50        0.0        0.0     0.091606     0.255814
# 2693  0.060382       1.00        0.0        0.0     0.215333     0.209302
#
#       Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  \
# 0                   0.0              0.0           0.843742    0.0
# 2421                0.0              0.0           0.404389    0.0
# 2424                0.0              0.0           0.403545    0.0
# 2426                0.0              0.0           0.402701    0.0
# 2429                0.0              0.0           0.402701    0.0
# ...                 ...              ...                ...    ...
# 2307                0.0              0.0           0.454304    0.0
# 3397                0.0              0.0           0.165180    0.0
# 2305                0.0              0.0           0.454907    0.0
# 452                 0.0              0.0           0.999156    0.0
# 2693                0.0              0.0           0.289728    0.0
#
#       clusterid_new
# 0                 0
# 2421              0
# 2424              0
# 2426              0
# 2429              0
# ...             ...
# 2307              3
# 3397              3
# 2305              3
# 452               3
# 2693              3
#
# [3999 rows x 11 columns]

# %%
km.groupby('clusterid_new').agg(['mean']).reset_index()
# Out:
#   clusterid_new   Balance cc1_miles cc2_miles cc3_miles Bonus_miles  \
#                      mean      mean      mean      mean        mean
# 0             0  0.023901  0.023195  0.008962  0.001054    0.012648
# 1             1  0.063535  0.728960  0.000619  0.006498    0.172970
# 2             2  0.048995  0.039004  0.016345  0.002229    0.033564
# 3             3  0.069234  0.644122  0.000805  0.005636    0.118637
#
#   Bonus_trans Flight_miles_12mo Flight_trans_12 Days_since_enroll Award
#          mean              mean            mean              mean  mean
# 0    0.075450          0.007353        0.012433          0.436112   0.0
# 1    0.234904          0.023160        0.040421          0.586139   1.0
# 2    0.121825          0.033427        0.059407          0.522892   1.0
# 3    0.200595          0.007313        0.011941          0.534640   0.0

# %%
plot=km.groupby('clusterid_new').agg(['mean']).reset_index()

# %%
plot
# Out:
#   clusterid_new   Balance cc1_miles cc2_miles cc3_miles Bonus_miles  \
#                      mean      mean      mean      mean        mean
# 0             0  0.023901  0.023195  0.008962  0.001054    0.012648
# 1             1  0.063535  0.728960  0.000619  0.006498    0.172970
# 2             2  0.048995  0.039004  0.016345  0.002229    0.033564
# 3             3  0.069234  0.644122  0.000805  0.005636    0.118637
#
#   Bonus_trans Flight_miles_12mo Flight_trans_12 Days_since_enroll Award
#          mean              mean            mean              mean  mean
# 0    0.075450          0.007353        0.012433          0.436112   0.0
# 1    0.234904          0.023160        0.040421          0.586139   1.0
# 2    0.121825          0.033427        0.059407          0.522892   1.0
# 3    0.200595          0.007313        0.011941          0.534640   0.0

# %%
list(enumerate(km.columns))
# Out:
# [(0, 'Balance'),
#  (1, 'cc1_miles'),
#  (2, 'cc2_miles'),
#  (3, 'cc3_miles'),
#  (4, 'Bonus_miles'),
#  (5, 'Bonus_trans'),
#  (6, 'Flight_miles_12mo'),
#  (7, 'Flight_trans_12'),
#  (8, 'Days_since_enroll'),
#  (9, 'Award'),
#  (10, 'clusterid_new')]

# %% [markdown]
# ## DBscan clustering

# %%
db=air

# %%
db.head(5)
# Out:
#    Balance  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0    28143          1          1          1          174            1
# 1    19244          1          1          1          215            2
# 2    41354          1          1          1         4123            4
# 3    14776          1          1          1          500            1
# 4    97752          4          1          1        43300           26
#
#    Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0                  0                0               7000      0
# 1                  0                0               6968      0
# 2                  0                0               7034      0
# 3                  0                0               6952      0
# 4               2077                4               6935      1

# %%
#Import the libraries
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dbscan = DBSCAN(eps=20, min_samples=50)
dbscan.fit(db)
# Out:
# DBSCAN(eps=20, min_samples=50)

# %%
#Noisy samples are given the label -1.
dbscan.labels_
# Out:
# array([-1, -1, -1, ..., -1, -1, -1], dtype=int64)

# %%
db['dbcluster']=pd.DataFrame(dbscan.labels_,columns=['cluster'])

# %%
db.head
# Out:
# <bound method NDFrame.head of       Balance  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  Bonus_trans  \
# 0       28143          1          1          1          174            1
# 1       19244          1          1          1          215            2
# 2       41354          1          1          1         4123            4
# 3       14776          1          1          1          500            1
# 4       97752          4          1          1        43300           26
# ...       ...        ...        ...        ...          ...          ...
# 3994    18476          1          1          1         8525            4
# 3995    64385          1          1          1          981            5
# 3996    73597          3          1          1        25447            8
# 3997    54899          1          1          1          500            1
# 3998     3016          1          1          1            0            0
#
#       Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award  dbcluster
# 0                     0                0               7000      0         -1
# 1                     0                0               6968      0         -1
# 2                     0                0               7034      0         -1
# 3                     0                0               6952      0         -1
# 4                  2077                4               6935      1         -1
# ...                 ...              ...                ...    ...        ...
# 3994                200                1               1403      1         -1
# 3995                  0                0               1395      1         -1
# 3996                  0                0               1402      1         -1
# 3997                500                1               1401      0         -1
# 3998                  0                0               1398      0         -1
#
# [3999 rows x 11 columns]>

# %% [markdown]
# ## Comparison of Hierarchical, kmeans and dbscan clustering techniques

# %%
air.shape
# Out:
# (3999, 11)

# %%
plt.figure(figsize=(15,30))
n=0
m=10  
for i in enumerate(air.columns):
        
    plt.subplot(11,3,i[0]+1)
    cr=air.columns
    sns.scatterplot(x=cr[n],y=cr[m], hue=None, 
    data=air, palette='dark', s=20);
    plt.legend(loc='lower right');
    plt.legend(loc='lower right');
    n=n+1
    m=m-1
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(15,30))
n=0
m=8 
for i in enumerate(df_norm1.columns):
        
    plt.subplot(9,2,i[0]+1)
    cr=df_norm1.columns
    sns.scatterplot(x=cr[n],y=cr[m], hue="Cluster", 
    data=df_norm1, palette='dark', s=20);
    plt.legend(loc='lower right');
    plt.legend(loc='lower right');
    n=n+1
    m=m-1

# %%
plt.figure(figsize=(15,35))
n=0
m=10 
for i in enumerate(km.columns):
        
    plt.subplot(11,3,i[0]+1)
    cr=km.columns
    sns.scatterplot(x=cr[n],y=cr[m], hue="clusterid_new", 
    data=km, palette='deep', s=20);
    plt.legend(loc='lower right');
    plt.legend(loc='lower right');
    n=n+1
    m=m-1

# %%
plt.figure(figsize=(15,30))
n=0
m=10 
for i in enumerate(db.columns):
        
    plt.subplot(11,3,i[0]+1)
    cr=db.columns
    sns.scatterplot(x=cr[n],y=cr[m], hue="dbcluster", 
    data=db, palette='deep', s=20);
    plt.legend(loc='lower right');
    plt.legend(loc='lower right');
    n=n+1
    m=m-1
